# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
data = pd.read_csv('News.csv',index_col=0)
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  class
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
data.shape
# Out:
# (44919, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44919 entries, 0 to 21416
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44919 non-null  object
#  1   text     44919 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   class    44919 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ MB

# %%
data['subject'].unique
# Out:
# <bound method Series.unique of 0             News
# 1             News
# 2             News
# 3             News
# 4             News
#            ...
# 21412    worldnews
# 21413    worldnews
# 21414    worldnews
# 21415    worldnews
# 21416    worldnews
# Name: subject, Length: 44919, dtype: object>

# %%
data['subject'].value_counts()
# Out:
# subject
# politicsNews                                                                                                                                                                                                                                                                                    11272
# worldnews                                                                                                                                                                                                                                                                                       10145
# News                                                                                                                                                                                                                                                                                             9050
# politics                                                                                                                                                                                                                                                                                         6838
# left-news                                                                                                                                                                                                                                                                                        4457
# Government News                                                                                                                                                                                                                                                                                  1570
# US_News                                                                                                                                                                                                                                                                                           775
# Middle-east                                                                                                                                                                                                                                                                                       770
#  of which Soros is a major financier.Mercy Corps: Vis a vis the Arab-Israeli conflict                                                                                                                                                                                                               2
#  and so is Mr. Katzenbach                                                                                                                                                                                                                                                                           2
#  high taxes                                                                                                                                                                                                                                                                                         2
#  Karl Marx is either a villain or a hero of social engineering                                                                                                                                                                                                                                      2
#  fell 5.6 percent Monday. Wynn Resortsslipped 1.2 percent. Las Vegas Sands fell as much as 2.1 percent before closing higher.   LIVE DRILL    Las Vegas has been at the forefront of active shooter training. ( Image Source: sinclairstoryline)Las Vegas Active Shooter Drills Back in 2014        2
#  claimed that hundreds of alternative media websites were producing  fake news  and  conspiracy  stories and therefore were unreliable as information sources. It wasn t long before the establishment began referencing these politicized lists                                                    2
#  state systems with outsized pretensions to power have reacted to their environments in two ways. The first strategy                                                                                                                                                                                2
#  decided not to seek re-election. While much of the mainstream media waxed poetic about his 30-year career                                                                                                                                                                                          2
#  the defense industry                                                                                                                                                                                                                                                                               2
#  a future nuclear family                                                                                                                                                                                                                                                                            2
#  Politics According to the Bible and (with Barry Asmus) The Poverty of Nations: A Sustainable Solution.Via: Townhall"                                                                                                                                                                               1
# Name: count, dtype: int64

# %%
data = data.drop(["title", "subject","date"], axis = 1)

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
# Shuffling
data = data.sample(frac=1)
data.reset_index(inplace=True)
data.drop(["index"], axis=1, inplace=True)

# %%
sns.countplot(data=data,
              x='class',
              order=data['class'].value_counts().index)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
# %pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from wordcloud) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from matplotlib->wordcloud) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\zulak\anaconda3\envs\fyp\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp39-cp39-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zulak\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zulak\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text_data):
    preprocessed_text = []
    
    for sentence in tqdm(text_data):
        sentence = re.sub(r'[^\w\s]', '', sentence)
        preprocessed_text.append(' '.join(token.lower()
                                  for token in str(sentence).split()
                                  if token not in stopwords.words('english')))

    return preprocessed_text

# %%
preprocessed_review = preprocess_text(data['text'].values)
data['text'] = preprocessed_review
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 44919/44919 [1:14:36<00:00, 10.03it/s]

# %%
# Real
consolidated = ' '.join(
    word for word in data['text'][data['class'] == 1].astype(str))
wordCloud = WordCloud(width=1600,
                      height=800,
                      random_state=21,
                      max_font_size=110,
                      collocations=False)
plt.figure(figsize=(15, 10))
plt.imshow(wordCloud.generate(consolidated), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Fake
consolidated = ' '.join(
    word for word in data['text'][data['class'] == 0].astype(str))
wordCloud = WordCloud(width=1600,
                      height=800,
                      random_state=21,
                      max_font_size=110,
                      collocations=False)
plt.figure(figsize=(15, 10))
plt.imshow(wordCloud.generate(consolidated), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer


def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx])
                  for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1],
                        reverse=True)
    return words_freq[:n]


common_words = get_top_n_words(data['text'], 20)
df1 = pd.DataFrame(common_words, columns=['Review', 'count'])

df1.groupby('Review').sum()['count'].sort_values(ascending=False).plot(
    kind='bar',
    figsize=(10, 6),
    xlabel="Top Words",
    ylabel="Count",
    title="Bar Chart of Top Words Frequency"
)
# Out:
# <Axes: title={'center': 'Bar Chart of Top Words Frequency'}, xlabel='Top Words', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

x_train, x_test, y_train, y_test = train_test_split(data['text'], 
                                                    data['class'], 
                                                    test_size=0.25)

# %%
data.head()
# Out:
#                                                 text  class
# 0  with whirlwind information coming us paul mana...      0
# 1  this powerful story courageous young woman fig...      0
# 2  stockholm reuters a passenger train derailed e...      1
# 3  new york city great melting pot diversity equa...      0
# 4  white house press secretary sean spicer known ...      0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
x_train = vectorization.fit_transform(x_train)
x_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
model = LogisticRegression()
model.fit(x_train, y_train)

# testing the model
print(accuracy_score(y_train, model.predict(x_train)))
print(accuracy_score(y_test, model.predict(x_test)))
predictions = model.predict(x_test)
cm = confusion_matrix(y_test, predictions, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()
# Out:
# 0.9939446110006234
# 0.9880676758682102

# %%
from pickle import dump
with open("fypLogistic.pkl", "wb") as f:
    dump(model, f, protocol=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 from pickle import dump
#       2 with open("fypLogistic.pkl", "wb") as f:
# ----> 3     dump(model, f, protocol=5)
#
# NameError: name 'model' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

# testing the model
print(accuracy_score(y_train, model.predict(x_train)))
print(accuracy_score(y_test, model.predict(x_test)))
predictions = model.predict(x_test)
cm = confusion_matrix(y_test, predictions, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()
# Out:
# 1.0
# 0.9961709706144256

# %%
with open("fypDecisionTree.pkl", "wb") as f:
    dump(model, f, protocol=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open("fypDecisionTree.pkl", "wb") as f:
# ----> 2     dump(model, f, protocol=5)
#
# NameError: name 'model' is not defined

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
model = KNeighborsClassifier(n_neighbors=3)
model.fit(x_train, y_train)

# testing the model
print(accuracy_score(y_train, model.predict(x_train)))
print(accuracy_score(y_test, model.predict(x_test)))
predictions = model.predict(x_test)
cm = confusion_matrix(y_test, predictions, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()
# Out:
# 0.731752203983496
# 0.656366874443455

# %%
with open("fypKNN.pkl", "wb") as f:
    dump(model, f, protocol=5)

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
model = svm.SVC()
model.fit(x_train, y_train)

# testing the model
print(accuracy_score(y_train, model.predict(x_train)))
print(accuracy_score(y_test, model.predict(x_test)))
predictions = model.predict(x_test)
cm = confusion_matrix(y_test, predictions, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=model.classes_)
disp.plot()
plt.show()
